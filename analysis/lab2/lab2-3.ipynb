# %% [markdown]
# `INFO 612 - LAB 2-3`
#
# ### SPATIAL STATISTICS
# ---
#
# For this lab I'm using the ArcGIS project previously created for lab 1 where I mapped all the Chinese restaurants across New York State and the NYC metropolitan area, according to the Foursquare Open Source Places dataset.  In this map I've separated restaurants into two point layers, urban and rural locations, according to the 2020 US Census Urban Areas TIGER/Line shapefile.
#
# This time I'm using the NCES Locales instead for more granular urban/rural classifications, and I will bring in all the restaurant points for the entire US.

# %%
import arcpy
from arcgis import GIS
import csv

# %%
# define paths to the multiple gdbs
main_gdb = r"C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec6_71a0f1\commondata\chinese-restaurants.gdb"
nces_gdb = r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\NCES_locales\5cfc2043-145e-48f7-a356-66c8e138838b.gdb"

# toggle on: overwriting existing feature classes
arcpy.env.overwriteOutput = True

# %%
# set workspace path
arcpy.env.workspace = main_gdb

# %%
# use current project
aprx = arcpy.mp.ArcGISProject("CURRENT")

# access the existing map object (index 0 because I only have one)
map_obj = aprx.listMaps("Map")[0]

# %% [markdown]
# First, I'll need to set the workspace to the NCES geodatabase to get the locales layer into the project, so I'll temporarily set the workspace to `nces_gdb`

# %%
# set workspace to NCES to get the locales layer
arcpy.env.workspace = nces_gdb

# %%
# list feature classes of current gdb
arcpy.ListFeatureClasses()
# Out:
# ['EDGE_LOCALE_CURRENT']

# %%
# add locales to map in main geodatabase
arcpy.management.MakeFeatureLayer('EDGE_LOCALE_CURRENT')
# Out:
# <Result 'EDGE_LOCALE_CURRENT_Layer1'>

# %%
# set workspace back to main
arcpy.env.workspace = main_gdb

# %%
# list layer names
for layer in map_obj.listLayers():
    print(layer.name)
# Out:
# Light Gray Reference
# EDGE_LOCALE_CURRENT_Layer
# NY-NJ-CT-PA
# tristate_restaurants_rural
# tristate_urban
# tristate_restaurants_urban
# tl_2020_us_state_tristate
# tl_2020_us_state
# tl 2020 census urban
# Light Gray Base

# %%
# rename the NCES layer
for layer in map_obj.listLayers():
    if "EDGE_LOCALE_CURRENT_Layer" in layer.name:
        layer.name = "NCES_Locales"

# list layers again to check that it was renamed
for layer in map_obj.listLayers():
    print(layer.name)
# Out:
# Light Gray Reference
# NCES_Locales
# NY-NJ-CT-PA
# tristate_restaurants_rural
# tristate_urban
# tristate_restaurants_urban
# tl_2020_us_state_tristate
# tl_2020_us_state
# tl 2020 census urban
# Light Gray Base

# %% [markdown]
# ### [NCES Classifications 2024](https://nces.ed.gov/programs/edge/Geographic/LocaleBoundaries)
# ---
#
# **CITIES** - inside an urban area with population 50,000 or more, inside a principal city
#
# `11` Large City - 250,000+
#
# `12` Midsize City - 100,000 - 250,000
#
# `13` Small City - < 100,000
#
# **SUBURBAN** - inside an urban area, outside a principal city
#
# `21` Large Suburban - 250,000+
#
# `22` Midsize Suburban - 100,000 - 250,000
#
# `23` Small Suburban - 50,000 - 100,000
#
# **TOWN** - inside an urban area with population less than 50,000
#
# `31` Fringe Town - less than 10 miles from an urban area with 50,000+
#
# `32` Distant Town - 10-35 miles from an urban area with 50,000+
#
# `33` Remote Town - 35+ miles from an urban area with 50,000+
#
# **RURAL** - outside an urban area
#
# `41` Fringe Rural - < 5 miles from an urban area of 50,000+ or < 2.5 miles from urban area with < 50,000
#
# `42` Distant Rural - 5-25 miles from an urban area of 50,000+ or > 2.5 miles from urban area with < 50,000
#
# `43` Remote Rural - > 25 miles from an urban area of 50,000+ and > 10 miles from urban area with < 50,000

# %%
# bring in the locale classifications to join with the attribute table to make the table more readable
csv_path = "NCES_locales.csv"

# create a dictionary from the csv
locale_lookup = {}
with open(csv_path, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        locale_lookup[row['LOCALE']] = row['LOC_NAME']

# %%
# add new field to the attribute table for the NCES_Locales layer
arcpy.management.AddField(
    in_table="NCES_Locales",
    field_name="LOC_NAME",
    field_type="TEXT",
    field_alias="Locale Name",
)
# Out:
# <Result 'NCES_Locales'>

# %%
# fill in locale names based on locale codes (thanks, genAI)
# also, make sure nothing is selected otherwise this won't work
with arcpy.da.UpdateCursor("NCES_Locales", ['LOCALE', 'LOC_NAME']) as cursor:
    for row in cursor:
        locale_code = str(row[0]) if row[0] is not None else None
        if locale_code and locale_code in locale_lookup:
            row[1] = locale_lookup[locale_code]
            cursor.updateRow(row)

# %%
# create a separate feature layer for each of the 12 locales (thanks, genAI)
for locale_code, loc_name in locale_lookup.items():
    # SQL where clause to filter by locale code
    where_clause = f"LOCALE = '{locale_code}'"
    
    # create layer name
    layer_name = f"{loc_name} ({locale_code})"
    
    # create feature layer named after the locale name with code
    arcpy.management.MakeFeatureLayer(
        in_features="NCES_Locales",
        out_layer=layer_name,
        where_clause=where_clause
    )
    print(f"Created feature layer: {layer_name}")
# Out:
# Created feature layer: Large City (11)
# Created feature layer: Midsize City (12)
# Created feature layer: Small City (13)
# Created feature layer: Large Suburban (21)
# Created feature layer: Midsize Suburban (22)
# Created feature layer: Small Suburban (23)
# Created feature layer: Fringe Town (31)
# Created feature layer: Distant Town (32)
# Created feature layer: Remote Town (33)
# Created feature layer: Fringe Rural (41)
# Created feature layer: Distant Rural (42)
# Created feature layer: Remote Rural (43)

# %% [markdown]
# ### Applying Symbology
# ---
# Now I can already see quite a difference between the census and NCES classifications.  For example, most of Long Island was classified as urban according to the census, but is a "large suburban" area according to NCES.
#
# Next, I manually updated the symbology of these new layers to group the territories by colour (city, suburban, town, and rural).  After this I realized I could also apply a continuous colour scheme over the locale names of the single NCES_Locales layer.

# %% [markdown]
# ### Bringing in the restaurants
# ---
# The CSV of Chinese restaurants that I created from Foursquare's Open Space Places data includes all the restaurants in Canada and the US.  I organized the restaurants into two layers, one for each country, and applied the same pink symbology to the new layers.

# %%
# create new feature layer from csv
arcpy.management.XYTableToPoint(
    in_table=r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\chinese_restaurants_cleaned.csv",
    out_feature_class=r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\chinese-restaurants.gdb\usa_restaurants",
    x_field="longitude",
    y_field="latitude",
    z_field=None,
    coordinate_system='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]];-400 -400 1000000000;-100000 10000;-100000 10000;8.98315284119521E-09;0.001;0.001;IsHighPrecision'
)
# Out:
# <Result 'C:\\Users\\jocel\\Documents\\ArcGIS\\Projects\\chinese-restaurants\\chinese-restaurants.gdb\\usa_restaurants'>

# %% [markdown]
# Since the Foursquare data uses WGS84 coordinates, I'll convert the data permanently so it's not projecting on-the-fly.

# %%
# change restaurants feature layer coordinates to match the map's projection permanently
arcpy.management.Project(
    in_dataset="usa_restaurants",
    out_dataset=r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\chinese-restaurants.gdb\usa_restaurants_albers",
    out_coor_system='PROJCS["North_America_Albers_Equal_Area_Conic",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-96.0],PARAMETER["Standard_Parallel_1",20.0],PARAMETER["Standard_Parallel_2",60.0],PARAMETER["Latitude_Of_Origin",40.0],UNIT["Meter",1.0]]',
    transform_method="WGS_1984_(ITRF00)_To_NAD_1983",
    in_coor_system='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]',
    preserve_shape="NO_PRESERVE_SHAPE",
    max_deviation=None,
    vertical="NO_VERTICAL"
)
# Out:
# <Result 'C:\\Users\\jocel\\Documents\\ArcGIS\\Projects\\chinese-restaurants\\chinese-restaurants.gdb\\usa_restaurants_albers'>

# %%
# checking the layer names again to verify which one i want to remove
am = aprx.activeMap
for layer in am.listLayers():
    print(layer.name)
# Out:
# Dark Gray Reference
# canada_restaurants
# us_restaurants
# tl_2020_us_state
# us_restaurants_firefly
# RURAL
# Remote Rural (43)
# Distant Rural (42)
# Fringe Rural (41)
# TOWNS
# Remote Town (33)
# Distant Town (32)
# Fringe Town (31)
# SUBURBS
# Small Suburban (23)
# Midsize Suburban (22)
# Large Suburban (21)
# CITIES
# Small City (13)
# Midsize City (12)
# Large City (11)
# NCES_Locales
# NY-NJ-CT-PA
# tristate_restaurants_rural
# tristate_urban
# tristate_restaurants_urban
# tl_2020_us_state_tristate
# tl 2020 census urban
# Dark Gray Base

# %%
# remove the original layer
layer_to_remove = map_obj.listLayers("usa_restaurants")[0]
map_obj.removeLayer(layer_to_remove)

# %%
# rename the reprojected layer
for layer in map_obj.listLayers():
    if "usa_restaurants_albers" in layer.name:
        layer.name = "us_restaurants"

# %%
# make a new layer for canadian restaurants only
arcpy.management.MakeFeatureLayer(
    in_features="us_restaurants",
    out_layer="canada_restaurants",
    where_clause="country = 'CA'",
    workspace=None,
    field_info="OBJECTID OBJECTID VISIBLE NONE;Shape Shape VISIBLE NONE;fsq_place_id fsq_place_id VISIBLE NONE;name name VISIBLE NONE;latitude latitude VISIBLE NONE;longitude longitude VISIBLE NONE;address address VISIBLE NONE;locality locality VISIBLE NONE;region region VISIBLE NONE;postcode postcode VISIBLE NONE;admin_region admin_region VISIBLE NONE;post_town post_town VISIBLE NONE;po_box po_box VISIBLE NONE;country country VISIBLE NONE;date_created date_created VISIBLE NONE;date_refreshed date_refreshed VISIBLE NONE;date_closed date_closed VISIBLE NONE;tel tel VISIBLE NONE;website website VISIBLE NONE;email email VISIBLE NONE;facebook_id facebook_id VISIBLE NONE;instagram instagram VISIBLE NONE;twitter twitter VISIBLE NONE;fsq_category_ids fsq_category_ids VISIBLE NONE;fsq_category_labels fsq_category_labels VISIBLE NONE;placemaker_url placemaker_url VISIBLE NONE;unresolved_flags unresolved_flags VISIBLE NONE;geom geom VISIBLE NONE;bbox bbox VISIBLE NONE"
)
# Out:
# <Result 'canada_restaurants'>

# %%
# delete canadian restaurants from us layer
# first make the selection
arcpy.management.SelectLayerByAttribute(
    in_layer_or_view="us_restaurants",
    selection_type="NEW_SELECTION",
    where_clause="country = 'CA'",
    invert_where_clause=None
)
# Out:
# <Result 'us_restaurants'>

# %%
# !!! this deleted too much, see note below
# make sure selection is active before running
# delete canadian restaurants
arcpy.management.DeleteFeatures("us_restaurants")

# %% [markdown]
# Whoops. That removed the canadian restaurants from all the layers that were made from usa_restaurants_albers in the gdb. I mistakenly thought the feature class in the gdb wouldn't be affected.  I'll have to import canadian restarants again.

# %%
# apply the same pink symbology as the tristate restaurants
arcpy.management.ApplySymbologyFromLayer(
    in_layer="us_restaurants",
    in_symbology_layer=r"NY-NJ-CT-PA\tristate_restaurants_rural",
    symbology_fields=None,
    update_symbology="DEFAULT"
)
# Out:
# <Result 'us_restaurants'>

# %%
# attempting to bring back canadian restaurants
arcpy.management.Project(
    in_dataset="usa_restaurants",
    out_dataset=r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\chinese-restaurants.gdb\canada_restaurants",
    out_coor_system='PROJCS["North_America_Albers_Equal_Area_Conic",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-96.0],PARAMETER["Standard_Parallel_1",20.0],PARAMETER["Standard_Parallel_2",60.0],PARAMETER["Latitude_Of_Origin",40.0],UNIT["Meter",1.0]]',
    transform_method="WGS_1984_(ITRF00)_To_NAD_1983",
    in_coor_system='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]',
    preserve_shape="NO_PRESERVE_SHAPE",
    max_deviation=None,
    vertical="NO_VERTICAL"
)
# Out:
# <Result 'C:\\Users\\jocel\\Documents\\ArcGIS\\Projects\\chinese-restaurants\\chinese-restaurants.gdb\\canada_restaurants'>

# %%
# delete us restaurants from canada layer
arcpy.management.SelectLayerByAttribute(
    in_layer_or_view="canada_restaurants",
    selection_type="NEW_SELECTION",
    where_clause="country = 'US'",
    invert_where_clause=None
)
# Out:
# <Result 'canada_restaurants'>

# %%
# make sure selection is active
arcpy.management.DeleteFeatures("canada_restaurants")
# Out:
# <Result 'canada_restaurants'>

# %%
# apply the same pink symbology as the us restaurants
arcpy.management.ApplySymbologyFromLayer(
    in_layer="canada_restaurants",
    in_symbology_layer=r"us_restaurants",
    symbology_fields=None,
    update_symbology="DEFAULT"
)
# Out:
# <Result 'canada_restaurants'>

# %% [markdown]
# **Note**: After applying the symbology, I manually changed the Feature Blend mode of these layers to 'Linear Dodge' so that they melt together when overlapping.

# %% [markdown]
# ### Bringing in ACS data on race and ethnicity
# ---
# I used `R` to gather census data on race and ethnicity by county and census tract.  To do this I had to create a variable with the shortcut `state.abb` to include all the states plus DC and Puerto Rico, since the Foursquare data for the US includes PR:
#
# `all_states <- c(state.abb, "DC", "PR")`
#
# Then I used `get_acs()` for the 2023 5-Year estimates.  This wasn't easily found in the tidycensus documentation, but was successfully revealed by generative AI.

# %%
# add the race and ethnicity shapefiles exported from R

# by census tract
path_race_tract = r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\census\acs2023_race_by_tract.shp"
path_ethnicity_tract = r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\census\acs2023_ethnicity_by_tract.shp"

# by county
path_race_county = r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\census\acs2023_race_by_county.shp"
path_ethnicity_county = r"C:\Users\jocel\Documents\ArcGIS\Projects\chinese-restaurants\census\acs2023_ethnicity_by_county.shp"

map_obj.addDataFromPath(path_race_tract)
map_obj.addDataFromPath(path_ethnicity_tract)
map_obj.addDataFromPath(path_race_county)
map_obj.addDataFromPath(path_ethnicity_county)

# %% [markdown]
# I manually applied unclassed colour symbology using the Inferno scheme to highlight all the census tracts that are at least 30% Chinese.
#
# There are no census tracts that have 100% Chinese residents, the most is 88%.  Overwhelmingly, most census tracts have 10% or fewer Chinese people.

# %%
# copy symbology to race layer, I'd like to see how the same illustrates white populations
arcpy.management.ApplySymbologyFromLayer(
    in_layer="acs2023_race_by_tract",
    in_symbology_layer="acs2023_ethnicity_by_tract",
    symbology_fields="NORMALIZATION_FIELD chinese whiteE",
    update_symbology="MAINTAIN"
)
# Out:
# <Result 'acs2023_race_by_tract'>

# %% [markdown]
# Unlike Chinese populations, there are a lot of census tracts that consist of 100% white people.  At a glance, it looks like these (along with tracts that are at least 30% white) tend to be more rural, and places where there are Chinese communities tend to be in cities.
#
# ### Calculating the relationship between locale type and Chinese population clusters
# ---
# To get a quantitative measure of this observation I'll use Summarize Within to see which locale types are associated with higher or lower percentages of Chinese people, then calculate the p-value from those results.

# %%
# calculating the percentage of chinese people into a new field
arcpy.management.CalculateField(
    in_table="acs2023_ethnicity_by_tract_Ex",
    field="ch_pct",
    expression="0 if !pop! == 0 else ((!chinese! * 100) / !pop!)",
    expression_type="PYTHON3",
    code_block="",
    field_type="FLOAT",
    enforce_domains="NO_ENFORCE_DOMAINS"
)
# Out:
# <Result 'acs2023_ethnicity_by_tract_Ex'>

# %%
# run summarize within to see which locale types are associated with higher or lower percentages of Chinese people
arcpy.analysis.SummarizeWithin(
    in_polygons="NCES_Locales",
    in_sum_features="acs2023_ethnicity_by_tract_Ex",
    out_feature_class="acs2023_ethnicity_by_tract_Ex_SummarizeWithin",
    keep_all_polygons="KEEP_ALL",
    sum_fields="ch_pct Mean",
    sum_shape="ADD_SHAPE_SUM",
    shape_unit="SQUAREKILOMETERS",
    group_field=None,
    add_min_maj="NO_MIN_MAJ",
    add_group_percent="NO_PERCENT",
    out_group_table=None
)
# Out:
# <Result 'C:\\Users\\jocel\\Documents\\ArcGIS\\Projects\\chinese-restaurants\\chinese-restaurants.gdb\\acs2023_ethnicity_by_tract_Ex_SummarizeWithin'>

# %%
# running spatial autocorrelation with the results of Summarize Within (thanks to generative AI for the idea to combine these)
arcpy.stats.SpatialAutocorrelation(
    Input_Feature_Class="acs2023_ethnicity_by_tract_Ex_SummarizeWithin",
    Input_Field="mean_ch_pct",
    Generate_Report="GENERATE_REPORT",
    Conceptualization_of_Spatial_Relationships="CONTIGUITY_EDGES_ONLY",
    Distance_Method="EUCLIDEAN_DISTANCE",
    Standardization="ROW",
    Distance_Band_or_Threshold_Distance=None,
    Weights_Matrix_File=None,
    number_of_neighbors=None
)
# Out:
# <Result '0.435678'>

# %% [markdown]
# ### Next steps
# ---
#
# The p-value shows that there is a statistically significant spatial clustering that mostly follows the urban-rural gradient.  Chinese populations prefer to cluster in cities and suburban areas, which was already visible when I mapped the percentage of Chinese people per census tract.
#
# Next I'd like to run similar analyses on the Chinese restaurant locations.  I did some quick analysis by state which was interesting:  the two states with the most Chinese residents had the fewest Chinese restaurants per 100 Chinese people.  Maybe this is because places like New York and San Francisco are densely populated, shorter distances to the nearest Chinese restaurant may negate the need for more restaurants.
#
# Visually, a map of Chinese restaurant locations across the US does show dense clusters in those cities, but they also appear quite evenly distributed across the country, with at least one restaurant even in the most remote locales.  I'm curious if Chinese restaurants locations exhibit a spatial structure that follows the urban-rural gradient, of if it's different somehow.

# %% [markdown]
# ### Distance to the nearest Chinese restaurant by locale type
# ---
# - spatial join ethnicity layer with NCES locales (feature to point: have their center in)
# - get centroids for each census tract (Feature to Point tool)
# - calculate distance from centroid to nearest chinese restaurant ()

# %%
# getting the centroid of each census tract
arcpy.management.FeatureToPoint(
    in_features="acs2023_ethnicity_by_tract_Ex",
    out_feature_class="ethn_tract_centroids",
    point_location="CENTROID"
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants_630192\\commondata\\chinese-restaurants.gdb\\ethn_tract_centroids'>

# %%
# spatial join (have their center in) between chinese people per census tract and NCES locales
arcpy.analysis.SpatialJoin(
    target_features="acs2023_ethnicity_by_tract_Ex",
    join_features="NCES_Locales",
    out_feature_class="chinese_per_localetype",
    join_operation="JOIN_ONE_TO_ONE",
    join_type="KEEP_ALL",
    field_mapping='GEOID "GEOID" true true false 80 Text 0 0,First,#,acs2023_ethnicity_by_tract_Ex,GEOID,0,79;NAME "NAME" true true false 81 Text 0 0,First,#,acs2023_ethnicity_by_tract_Ex,NAME,0,80;pop "population" true true false 8 Double 0 0,First,#,acs2023_ethnicity_by_tract_Ex,pop,-1,-1;asian "asian alone" true true false 8 Double 0 0,First,#,acs2023_ethnicity_by_tract_Ex,asian,-1,-1;chinese "chinese" true true false 8 Double 0 0,First,#,acs2023_ethnicity_by_tract_Ex,chinese,-1,-1;taiwan "taiwanese" true true false 8 Double 0 0,First,#,acs2023_ethnicity_by_tract_Ex,taiwan,-1,-1;cmb_asian "asian multiracial" true true false 8 Double 0 0,First,#,acs2023_ethnicity_by_tract_Ex,cmb_asian,-1,-1;cmb_chns "chinese multiracial" true true false 8 Double 0 0,First,#,acs2023_ethnicity_by_tract_Ex,cmb_chns,-1,-1;ch_pct "percent chinese" true true false 4 Float 0 0,First,#,acs2023_ethnicity_by_tract_Ex,ch_pct,-1,-1;LOCALE "Locale Code" true true false 2 Text 0 0,First,#,NCES_Locales,LOCALE,0,1;STATEFP "State FIPS code" true true false 2 Text 0 0,First,#,NCES_Locales,STATEFP,0,1;LOC_NAME "Locale Name" true true false 255 Text 0 0,First,#,NCES_Locales,LOC_NAME,0,254',
    match_option="HAVE_THEIR_CENTER_IN",
    search_radius=None,
    distance_field_name="",
    match_fields=None
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants_630192\\commondata\\chinese-restaurants.gdb\\chinese_per_localetype'>

# %%
# re-project layer to give it a projected coordinate system (equidistant for the most accurate distance measurements)

arcpy.management.Project(
    in_dataset="ethn_tract_centroids",
    out_dataset="centroids_Projected",
    out_coor_system='PROJCS["NAD_1983_2011_USA_Contiguous_Equidistant_Conic",GEOGCS["GCS_NAD_1983_2011",DATUM["D_NAD_1983_2011",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Equidistant_Conic"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-96.0],PARAMETER["Standard_Parallel_1",33.0],PARAMETER["Standard_Parallel_2",45.0],PARAMETER["Latitude_Of_Origin",39.0],UNIT["Meter",1.0]]',
    transform_method="'WGS_1984_(ITRF00)_To_NAD_1983 + WGS_1984_(ITRF08)_To_NAD_1983_2011'",
    in_coor_system='GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]',
    preserve_shape="NO_PRESERVE_SHAPE",
    max_deviation=None,
    vertical="NO_VERTICAL"
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants-dec7_41429d\\commondata\\chinese-restaurants.gdb\\centroids_Projected'>

# %%
# find distance to the nearest chinese restaurant

arcpy.analysis.Near(
    in_features="centroids_Projected",
    near_features="us_restaurants",
    search_radius=None,
    location="NO_LOCATION",
    angle="NO_ANGLE",
    method="PLANAR",
    field_names="NEAR_FID NEAR_FID;NEAR_DIST NEAR_DIST",
    distance_unit="Kilometers",
    match_fields=None
)
# Out:
# <Result 'centroids_Projected'>

# %% [markdown]
# ### Chinese restuarants per by locale type
# ---
# 1. general population
# 2. chinese population
#
# - spatial join census tracts layer with NCES locales
# - summarize number of restaurants per census tract (summarize within)

# %%
# find number of restaurants per census tract
arcpy.analysis.SpatialJoin(
    target_features="chinese_per_localetype_havecenterin",
    join_features="us_restaurants",
    out_feature_class="restaurants_per_tract",
    join_operation="JOIN_ONE_TO_ONE",
    join_type="KEEP_ALL",
    field_mapping=r'GEOID_First "GEOID_First" true true false 255 Text 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,GEOID,0,79;NAME_First "NAME_First" true true false 255 Text 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,NAME,0,80;pop_First "pop_First" true true false 255 Double 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,pop,-1,-1;asian_First "asian_First" true true false 255 Double 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,asian,-1,-1;chinese_First "chinese_First" true true false 255 Double 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,chinese,-1,-1;ch_pct_First "ch_pct_First" true true false 255 Double 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,ch_pct,-1,-1;cmb_asian_First "cmb_asian_First" true true false 255 Double 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,cmb_asian,-1,-1;cmb_chns_First "cmb_chns_First" true true false 255 Double 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,cmb_chns,-1,-1;taiwan_First "taiwan_First" true true false 255 Double 0 0,First,#,C:\Users\jfung53\Documents\ArcGIS\Packages\chinese-restaurants-dec2_a28955\commondata\chinese-restaurants.gdb\chinese_per_localetype,taiwan,-1,-1;LOCALE "Locale Code" true true false 2 Text 0 0,First,#,NCES_Locales,LOCALE,0,1;STATEFP "State FIPS code" true true false 2 Text 0 0,First,#,NCES_Locales,STATEFP,0,1;LOC_NAME "Locale Name" true true false 255 Text 0 0,First,#,NCES_Locales,LOC_NAME,0,254;fsq_place_id "fsq_place_id" true true false 8000 Text 0 0,First,#,us_restaurants,fsq_place_id,0,7999;name "name" true true false 8000 Text 0 0,First,#,us_restaurants,name,0,7999;latitude "latitude" true true false 8 Double 0 0,First,#,us_restaurants,latitude,-1,-1;longitude "longitude" true true false 8 Double 0 0,First,#,us_restaurants,longitude,-1,-1;address "address" true true false 8000 Text 0 0,First,#,us_restaurants,address,0,7999;locality "locality" true true false 8000 Text 0 0,First,#,us_restaurants,locality,0,7999;region "region" true true false 8000 Text 0 0,First,#,us_restaurants,region,0,7999;postcode "postcode" true true false 8 Double 0 0,First,#,us_restaurants,postcode,-1,-1;admin_region "admin_region" true true false 8000 Text 0 0,First,#,us_restaurants,admin_region,0,7999;post_town "post_town" true true false 8000 Text 0 0,First,#,us_restaurants,post_town,0,7999;po_box "po_box" true true false 8000 Text 0 0,First,#,us_restaurants,po_box,0,7999;country "country" true true false 8000 Text 0 0,First,#,us_restaurants,country,0,7999;date_created "date_created" true true false 8 DateOnly 0 0,First,#,us_restaurants,date_created,-1,-1;date_refreshed "date_refreshed" true true false 8 DateOnly 0 0,First,#,us_restaurants,date_refreshed,-1,-1;date_closed "date_closed" true true false 8 DateOnly 0 0,First,#,us_restaurants,date_closed,-1,-1;fsq_category_ids "fsq_category_ids" true true false 8000 Text 0 0,First,#,us_restaurants,fsq_category_ids,0,7999;fsq_category_labels "fsq_category_labels" true true false 8000 Text 0 0,First,#,us_restaurants,fsq_category_labels,0,7999',
    match_option="INTERSECT",
    search_radius=None,
    distance_field_name="",
    match_fields=None
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants-dec6_71a0f1\\commondata\\chinese-restaurants.gdb\\restaurants_per_tract'>

# %%
# join to add distance to nearest restaurant by census tract polygons

arcpy.management.JoinField(
    in_data="acs2023_ethnicity_by_tract_Ex",
    in_field="GEOID",
    join_table="chinese_per_localetype_havecenterin",
    join_field="GEOID",
    fields="LOCALE;STATEFP;LOC_NAME",
    fm_option="NOT_USE_FM",
    field_mapping=None,
    index_join_fields="NO_INDEXES"
)
# Out:
# <Result 'acs2023_ethnicity_by_tract_Ex'>

# %% [markdown]
# ### Looking for metrics to measure clusters of restaurants according to locale type and presence of Chinese people
# ---

# %%
# spatial join to get locale types per tract

arcpy.management.AddSpatialJoin(
    target_features="restaurants_per_tract",
    join_features="NCES_Locales",
    join_operation="JOIN_ONE_TO_ONE",
    join_type="KEEP_ALL",
    field_mapping='LOCALE "Locale Code" true true false 2 Text 0 0,First,#,NCES_Locales,LOCALE,0,1;STATEFP "State FIPS code" true true false 2 Text 0 0,First,#,NCES_Locales,STATEFP,0,1;GEO_YEAR "TIGER file year" true true false 4 Text 0 0,First,#,NCES_Locales,GEO_YEAR,0,3;LOC_NAME "Locale Name" true true false 255 Text 0 0,First,#,NCES_Locales,LOC_NAME,0,254;SHAPE_Length "SHAPE_Length" false true true 8 Double 0 0,First,#,NCES_Locales,SHAPE_Length,-1,-1;SHAPE_Area "SHAPE_Area" false true true 8 Double 0 0,First,#,NCES_Locales,SHAPE_Area,-1,-1',
    match_option="HAVE_THEIR_CENTER_IN",
    search_radius=None,
    distance_field_name="",
    permanent_join="PERMANENT_FIELDS",
    match_fields=None
)
# Out:
# <Result 'C:\\Users\\jocel\\OneDrive\\Documents\\ArcGIS\\Packages\\chinese-restaurants-dec8_446fd4\\commondata\\chinese-restaurants.gdb\\restaurants_per_tract'>

# %% [markdown]
# # Cluster and Outlier Analysis (Local Moran's I)
#
# I'd like to find out the relationship between clusters of restaurants in urban/rural locales and the percentage of chinese people. My hypothesis is that chinese restaurants do not necessarily cluster only in the urban chinese ethnic enclaves.

# %%
# project the layer before running cluster and outlier analysis

arcpy.management.Project(
    in_dataset="restaurants_per_tract",
    out_dataset="restaurants_per_trac_Projected",
    out_coor_system='PROJCS["North_America_Albers_Equal_Area_Conic",GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Albers"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",-96.0],PARAMETER["Standard_Parallel_1",20.0],PARAMETER["Standard_Parallel_2",60.0],PARAMETER["Latitude_Of_Origin",40.0],UNIT["Meter",1.0]]',
    transform_method=None,
    in_coor_system='GEOGCS["GCS_North_American_1983",DATUM["D_North_American_1983",SPHEROID["GRS_1980",6378137.0,298.257222101]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]',
    preserve_shape="NO_PRESERVE_SHAPE",
    max_deviation=None,
    vertical="NO_VERTICAL"
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants-dec12_a8c841\\commondata\\chinese-restaurants.gdb\\restaurants_per_trac_Projected'>

# %%
# cluster and outlier analysis (anselin local moran's i) for chinese people

arcpy.stats.ClustersOutliers(
    Input_Feature_Class="restaurants_per_trac_Projected",
    Input_Field="rest_per_100ch",
    Output_Feature_Class="rest_per_chppl_ClustersOutliers",
    Conceptualization_of_Spatial_Relationships="INVERSE_DISTANCE",
    Distance_Method="EUCLIDEAN_DISTANCE",
    Standardization="ROW",
    Distance_Band_or_Threshold_Distance=None,
    Weights_Matrix_File=None,
    Apply_False_Discovery_Rate__FDR__Correction="NO_FDR",
    Number_of_Permutations=499,
    number_of_neighbors=None
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants-dec12_a8c841\\commondata\\chinese-restaurants.gdb\\rest_per_chppl_ClustersOutliers'>

# %%
# adding the locale types back in, they didn't make it through the Cluster/Outlier tool. 

arcpy.analysis.SpatialJoin(
    target_features="rest_per_chppl_ClustersOutliers",
    join_features="NCES_Locales",
    out_feature_class="ClusterOutlier_with_locales",
    join_operation="JOIN_ONE_TO_ONE",
    join_type="KEEP_ALL",
    field_mapping='SOURCE_ID "SOURCE_ID" true false false 4 Long 0 0,First,#,rest_per_chppl_ClustersOutliers,SOURCE_ID,-1,-1;rest_per_100ch "rest_per_100ch" true true false 4 Float 0 0,First,#,rest_per_chppl_ClustersOutliers,rest_per_100ch,-1,-1;LMiIndex "LMiIndex IDW 1349350 RS" true true false 8 Double 0 0,First,#,rest_per_chppl_ClustersOutliers,LMiIndex,-1,-1;LMiZScore "LMiZScore IDW 1349350 RS" true true false 8 Double 0 0,First,#,rest_per_chppl_ClustersOutliers,LMiZScore,-1,-1;LMiPValue "LMiPValue IDW 1349350 RS" true true false 8 Double 0 0,First,#,rest_per_chppl_ClustersOutliers,LMiPValue,-1,-1;COType "COType IDW 1349350 RS" true true false 2 Text 0 0,First,#,rest_per_chppl_ClustersOutliers,COType,0,1;NNeighbors "NNeighbors IDW 1349350 RS" true true false 4 Long 0 0,First,#,rest_per_chppl_ClustersOutliers,NNeighbors,-1,-1;ZTransform "ZTransform IDW 1349350 RS" true true false 8 Double 0 0,First,#,rest_per_chppl_ClustersOutliers,ZTransform,-1,-1;SpatialLag "SpatialLag IDW 1349350 RS" true true false 8 Double 0 0,First,#,rest_per_chppl_ClustersOutliers,SpatialLag,-1,-1;LOCALE "Locale Code" true true false 2 Text 0 0,First,#,NCES_Locales,LOCALE,0,1;STATEFP "State FIPS code" true true false 2 Text 0 0,First,#,NCES_Locales,STATEFP,0,1;LOC_NAME "Locale Name" true true false 255 Text 0 0,First,#,NCES_Locales,LOC_NAME,0,254',
    match_option="INTERSECT",
    search_radius=None,
    distance_field_name="",
    match_fields=None
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants-dec12_a8c841\\commondata\\chinese-restaurants.gdb\\ClusterOutlier_with_locales'>

# %% [markdown]
# ## Tables Exported
# ---
#
# I exported the tables to analyze elsewhere.

# %% [markdown]
# ### Further analysis
# ---
# Next I'd like to analyze restaurant names by locale type. I'll do this outside of ArcGIS using natural language processing tools.

# %%
# spatial join to assign locale type to restaurants

arcpy.analysis.SpatialJoin(
    target_features="us_restaurants",
    join_features="NCES_Locales",
    out_feature_class="us_restaurants_by_locale",
    join_operation="JOIN_ONE_TO_ONE",
    join_type="KEEP_ALL",
    field_mapping='fsq_place_id "fsq_place_id" true true false 8000 Text 0 0,First,#,us_restaurants,fsq_place_id,0,7999;name "name" true true false 8000 Text 0 0,First,#,us_restaurants,name,0,7999;latitude "latitude" true true false 8 Double 0 0,First,#,us_restaurants,latitude,-1,-1;longitude "longitude" true true false 8 Double 0 0,First,#,us_restaurants,longitude,-1,-1;address "address" true true false 8000 Text 0 0,First,#,us_restaurants,address,0,7999;locality "locality" true true false 8000 Text 0 0,First,#,us_restaurants,locality,0,7999;region "region" true true false 8000 Text 0 0,First,#,us_restaurants,region,0,7999;postcode "postcode" true true false 8 Double 0 0,First,#,us_restaurants,postcode,-1,-1;admin_region "admin_region" true true false 8000 Text 0 0,First,#,us_restaurants,admin_region,0,7999;post_town "post_town" true true false 8000 Text 0 0,First,#,us_restaurants,post_town,0,7999;po_box "po_box" true true false 8000 Text 0 0,First,#,us_restaurants,po_box,0,7999;country "country" true true false 8000 Text 0 0,First,#,us_restaurants,country,0,7999;date_created "date_created" true true false 8 DateOnly 0 0,First,#,us_restaurants,date_created,-1,-1;date_refreshed "date_refreshed" true true false 8 DateOnly 0 0,First,#,us_restaurants,date_refreshed,-1,-1;date_closed "date_closed" true true false 8 DateOnly 0 0,First,#,us_restaurants,date_closed,-1,-1;tel "tel" true true false 8000 Text 0 0,First,#,us_restaurants,tel,0,7999;website "website" true true false 8000 Text 0 0,First,#,us_restaurants,website,0,7999;email "email" true true false 8000 Text 0 0,First,#,us_restaurants,email,0,7999;facebook_id "facebook_id" true true false 8 Double 0 0,First,#,us_restaurants,facebook_id,-1,-1;instagram "instagram" true true false 8000 Text 0 0,First,#,us_restaurants,instagram,0,7999;twitter "twitter" true true false 8000 Text 0 0,First,#,us_restaurants,twitter,0,7999;fsq_category_ids "fsq_category_ids" true true false 8000 Text 0 0,First,#,us_restaurants,fsq_category_ids,0,7999;fsq_category_labels "fsq_category_labels" true true false 8000 Text 0 0,First,#,us_restaurants,fsq_category_labels,0,7999;placemaker_url "placemaker_url" true true false 8000 Text 0 0,First,#,us_restaurants,placemaker_url,0,7999;unresolved_flags "unresolved_flags" true true false 8000 Text 0 0,First,#,us_restaurants,unresolved_flags,0,7999;geom "geom" true true false 8000 Text 0 0,First,#,us_restaurants,geom,0,7999;bbox "bbox" true true false 8000 Text 0 0,First,#,us_restaurants,bbox,0,7999;still_open "still_open" true true false 2 Short 0 0,First,#,us_restaurants,still_open,-1,-1;LOCALE "Locale Code" true true false 2 Text 0 0,First,#,NCES_Locales,LOCALE,0,1;STATEFP "State FIPS code" true true false 2 Text 0 0,First,#,NCES_Locales,STATEFP,0,1;GEO_YEAR "TIGER file year" true true false 4 Text 0 0,First,#,NCES_Locales,GEO_YEAR,0,3;LOC_NAME "Locale Name" true true false 255 Text 0 0,First,#,NCES_Locales,LOC_NAME,0,254;SHAPE_Length "SHAPE_Length" false true true 8 Double 0 0,First,#,NCES_Locales,SHAPE_Length,-1,-1;SHAPE_Area "SHAPE_Area" false true true 8 Double 0 0,First,#,NCES_Locales,SHAPE_Area,-1,-1',
    match_option="INTERSECT",
    search_radius=None,
    distance_field_name="",
    match_fields=None
)
# Out:
# <Result 'C:\\Users\\jfung53\\Documents\\ArcGIS\\Packages\\chinese-restaurants-dec7_41429d\\commondata\\chinese-restaurants.gdb\\us_restaurants_by_locale'>
